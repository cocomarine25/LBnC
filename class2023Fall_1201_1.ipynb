# %% [markdown]
# <a href="https://colab.research.google.com/github/cocomarine25/LBnC/blob/main/class2023Fall_1201_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install libcurl4-openssl-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libcurl4-openssl-dev is already the newest version (7.81.0-1ubuntu1.14).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %%
# %%writefile RequestLikePython.cpp
# #include <iostream> /* include는 파이썬의 import와 같다 */
# #include <curl/curl.h>
# #include <string>
#
# size_t resCallback(void *p_resContents, size_t sizeOneUnit, size_t numUnits, void *p_userBuffer) {
#     ((std::string*)p_userBuffer)->append((char*)p_resContents, sizeOneUnit * numUnits);
#     return sizeOneUnit * numUnits;
# }
#
# int main(int argc, char *argv[]) {
#     if (argc != 2) {
#         std::cerr << "Usage: " << argv[0] << " <URL>" << std::endl;
#         return 1;
#     }
#
#     CURL *p_curl;
#     CURLcode resCode;
#     std::string userBuffer;
#
#     p_curl = curl_easy_init();
#     if(p_curl) {
#         curl_easy_setopt(p_curl, CURLOPT_URL, argv[1]);
#         curl_easy_setopt(p_curl, CURLOPT_WRITEFUNCTION, resCallback);
#         curl_easy_setopt(p_curl, CURLOPT_WRITEDATA, &userBuffer);
#         resCode = curl_easy_perform(p_curl);
#         curl_easy_cleanup(p_curl);
#         // Should be filled
#         std::cout << userBuffer << std::endl;
#     }
#     return 0;
# }
# Out:
# Writing RequestLikePython.cpp

# %%
# !g++ -o crequest RequestLikePython.cpp -lcurl
# !./crequest https://www.naver.com/ /* 네이버에서 크롤링을 해와라 */
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %%
import requests
requests.get("https://www.naver.com/").text
# Out:
# '   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description
# ...
