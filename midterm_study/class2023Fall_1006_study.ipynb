# %% [markdown]
# <a href="https://colab.research.google.com/github/cocomarine25/LBnC/blob/main/midterm_study/class2023Fall_1006_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **1. Understanding Web Scraping and its Applications**
#
# ---
#
# Web scraping is the process of extracting data from websites. This data can be anything: text, images, links, and more. It's a way to programmatically interact with a webpage, allowing you to pull data from online sources that may not have an API.
#
# **Applications**:
# - Price comparison
# - Data collection for research
# - Job listings
# - Monitoring changes on websites
# - And many more...
#
# ---
#
# ### **2. Introduction to the BeautifulSoup Library**
#
# ---
#
# Beautiful Soup is a Python library for web scraping purposes. It creates parse trees from page source code that can be used to extract data easily.
#
# **Installation**:
# ```python
# !pip install beautifulsoup4
# ```
#
# ---
#
# ### **3. Extracting Data from Websites**
#
# ---
#
# To begin with, let's extract the title of a webpage.
#
# **Example**:
#
# ```python
# import requests
# from bs4 import BeautifulSoup
#
# URL = 'https://www.example.com'
# page = requests.get(URL)
# soup = BeautifulSoup(page.content, 'html.parser')
#
# # Extracting the title of the webpage
# title = soup.title.string
# print(title)
# ```
#
# ---
#
# ### **4. Handling Different HTML Elements**
#
# ---
#
# #### **a. Extracting Paragraphs**
#
# ```python
# # Extracting all paragraphs from the page
# paragraphs = soup.find_all('p')
# for p in paragraphs:
#     print(p.text)
# ```
#
# #### **b. Extracting Links**
#
# ```python
# # Extracting all links from the page
# links = soup.find_all('a')
# for link in links:
#     print(link.get('href'))
# ```
#
# #### **c. Extracting with Class and ID**
#
# HTML elements can also have attributes like classes and IDs. BeautifulSoup can filter elements based on these attributes.
#
# ```python
# # Extracting elements with a specific class
# specific_class_elements = soup.find_all(class_='specific-class')
#
# # Extracting elements with a specific ID
# specific_id_elements = soup.find_all(id='specific-id')
# ```
#
# #### **d. Navigating the Tree Structure**
#
# BeautifulSoup allows you to navigate the parse tree. This means you can access child elements, siblings, and even parent elements.
#
# ```python
# # Accessing the first child of an element
# first_child = soup.p.contents[0]
#
# # Accessing the parent of an element
# parent_element = soup.p.parent
# ```
#
#
#
# ---

# %% [markdown]
# **------------------------------코드 연습 시작 !------------------------------**

# %% [markdown]
# **Extracting Data from Websites (크롤링)**

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://n.news.naver.com/article/055/0001097646?cds=news_media_pc&type=editn'
page = requests.get(URL)
print(page)
print(type(page))
print(dir(page))
# print(page.content) # html 전체, 줄글로 나와서 모양은 이쁘지 않음

print('\n')

soup = BeautifulSoup(page.content, 'html.parser') # parser는 html에서 묶여있는 것들을 해체하는 코드
# print(soup) # 그래서 soup를 print하면 모양이 이쁘게 나옴
print(type(soup))
print(dir(soup))


# Extracting the title of the webpage
title = soup.title.string
print(title)

# 가장 처음에 내 컴퓨터에서 코드를 전송할 때 = 내 컴퓨터 -> (공유기) -> isp -> 구글
# 구글이 .get를 만났을 때 = 구글 -> isp -> 네이버
# 네이버가 페이지에 200코드를 붙여 다시 구글에 전송 = 네이버 -> isp -> 구글
# 구글이 내 컴퓨터에 print되는 글자를 전송 = 구글 -> isp -> 내 컴퓨터
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
#
#
# <class 'bs4.BeautifulSoup'>
# ['ASCII_SPACES', 'DEFAULT_BUILDER_FEATURES', 'DEFAULT_INTERESTING_STRING_TYPES', 'NO_PARSER_SPECIFIED_WARNING', 'ROOT_TAG_NAME', '__bool__', '__call__', '__class__', '__contains__', '__copy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_all_strings', '_decode_markup', '_feed', '_find_all', '_find_one', '_is_xml', '_lastRecursiveChild', '_last_descendant', '_linkage_fixer', '_markup_is_url', '_markup_resembles_filename', '_most_recent_element', '_namespaces', '_popToTag', '_should_pretty_print', 'append', 'attrs', 'builder', 'can_be_empty_element', 'cdata_list_attributes', 'childGenerator', 'children', 'clear', 'contains_replacement_characters', 'contents', 'currentTag', 'current_data', 'declared_html_encoding', 'decode', 'decode_contents', 'decompose', 'decomposed', 'default', 'descendants', 'element_classes', 'encode', 'encode_contents', 'endData', 'extend', 'extract', 'fetchNextSiblings', 'fetchParents', 'fetchPrevious', 'fetchPreviousSiblings', 'find', 'findAll', 'findAllNext', 'findAllPrevious', 'findChild', 'findChildren', 'findNext', 'findNextSibling', 'findNextSiblings', 'findParent', 'findParents', 'findPrevious', 'findPreviousSibling', 'findPreviousSiblings', 'find_all', 'find_all_next', 'find_all_previous', 'find_next', 'find_next_sibling', 'find_next_siblings', 'find_parent', 'find_parents', 'find_previous', 'find_previous_sibling', 'find_previous_siblings', 'format_string', 'formatter_for_name', 'get', 'getText', 'get_attribute_list', 'get_text', 'handle_data', 'handle_endtag', 'handle_starttag', 'has_attr', 'has_key', 'hidden', 'index', 'insert', 'insert_after', 'insert_before', 'interesting_string_types', 'isSelfClosing', 'is_empty_element', 'is_xml', 'known_xml', 'markup', 'name', 'namespace', 'new_string', 'new_tag', 'next', 'nextGenerator', 'nextSibling', 'nextSiblingGenerator', 'next_element', 'next_elements', 'next_sibling', 'next_siblings', 'object_was_parsed', 'open_tag_counter', 'original_encoding', 'parent', 'parentGenerator', 'parents', 'parse_only', 'parserClass', 'parser_class', 'popTag', 'prefix', 'preserve_whitespace_tag_stack', 'preserve_whitespace_tags', 'prettify', 'previous', 'previousGenerator', 'previousSibling', 'previousSiblingGenerator', 'previous_element', 'previous_elements', 'previous_sibling', 'previous_siblings', 'pushTag', 'recursiveChildGenerator', 'renderContents', 'replaceWith', 'replaceWithChildren', 'replace_with', 'replace_with_children', 'reset', 'select', 'select_one', 'setup', 'smooth', 'string', 'string_container', 'string_container_stack', 'strings', 'stripped_strings', 'tagStack', 'text', 'unwrap', 'wrap']
# [취재파일] 철도 업무 중 음주 적발, 형사처벌은 '복불복' ①

# %%
# HTTP Error

# 2xx는 성공
# 3xx는 대체제를 받음(뉴스 기사 링크를 복사해두고 20년 뒤에 링크에 들어가보면 기사가 없을 확률이 매우 높음, 이럴때 네이버가 뉴스 메인 홈페이지 등으로 연결해줄 경우 3xx에러)
# 4xx는 내 잘못으로 실패(없는 곳에 접속 시도, 404 page not found)
# 5xx는 네이버 서버의 문제가 있음

# %% [markdown]
# #**Handling Different HTML Elements**

# %% [markdown]
# **Extracting Paragraphs**

# %%
# Extracting all paragraphs from the page
# p로 태그된 것(<p로 시작하는 부분)을 전부 찾음

paragraphs = soup.find_all('p')
for p in paragraphs:
    print(p.text) # .text로 글씨만
# Out:
# 언론사를 구독하면 메인에서 바로 볼 수 있어요!
#
#
# SBS 언론사 구독 해지되었습니다.
#
#
# 언론사가 심층기획 기사로선정한 기사입니다.
# 언론사별 바로가기
# 닫기
#
# 이동 통신망을 이용하여 음성을 재생하면 별도의 데이터 통화료가 부과될 수 있습니다.
#
# 박찬범 기자 cbcb@sbs.co.kr
#
# ‘하나라도 더 알려주고 싶은 기자'
# Copyright ⓒ SBS. All rights reserved. 무단 전재, 재배포 및 AI학습 이용 금지
# 기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. 언론사는 개별 기사를 2개 이상 섹션으로 중복 분류할 수 있습니다.
# 구독
# 메인에서 바로 보는 언론사 편집 뉴스 지금 바로 구독해보세요!
# 구독중
# 메인에서 바로 보는 언론사 편집 뉴스 지금 바로 확인해보세요!
# 기사 내용을 기반으로 자동 추출합니다.
# 기사 추천은 24시간 내 50회까지 참여할 수 있습니다.
#
# 모두에게 보여주고 싶은 기사라면?beta
#
# 이 기사를 추천합니다 버튼을 눌러주세요.  집계 기간 동안 추천을 많이 받은 기사는 네이버 자동 기사배열 영역에 추천 요소로 활용됩니다.
#
# 레이어 닫기
#
# 구독해주셔서 감사합니다
# 구독한 연재는 설정 페이지에서확인할 수 있습니다
# SBS 댓글 정책에 따라 SBS에서 제공하는 정치섹션 기사의 본문 하단에는 댓글 서비스를 제공하지 않습니다.
# 500km 하마스 땅굴…두 차례 빈손 퇴각, 이번 지상전은
# 안철수-이준석 공방에…"초상집 상주끼리 그만 싸워라"
# "농촌 살리자" 50억 쓰고…하루 1명 찾는 '유령 테마공원'
# 예약 받고선 "안 갈 수도"…출국 앞둔 1,500명 발 동동
# 택시 막고 실랑이…"멀쩡하게 살아있네" 피해자들 분통
# 손자 부르며 "브레이크 안돼"…운전한 할머니 혐의 벗어
# 뉴스 추천 알고리즘이 궁금하다면?
# 예약 받고선 "안 갈 수도"…출국 앞둔 1,500명 발 동동
# "농촌 살리자" 50억 쓰고…하루 1명 찾는 '유령 테마공원'
# [포착] 길에 떨어진 '네모 어묵' 절대 만지시면 안 됩니다
# 택시 막고 실랑이…"멀쩡하게 살아있네" 피해자들 분통
# 팔 다친 인질 붕대 감는 영상…하마스가 꺼낸 '인간 방패'
# "국제결혼 끔찍…아이들 실질적 문맹" 현직교사 글 논란
# 안철수-이준석 공방에…"초상집 상주끼리 그만 싸워라"
# "농촌 살리자" 50억 쓰고…하루 1명 찾는 '유령 테마공원'
# 복지부 장관 "의대 증원, 못 미룬다"…국립의대 TF 구성
# 김영배 "집단 뇌피셜"…서울중앙지검장 "개인 변호사냐"
# 최근 일주일 이내 업데이트된 기자 중에서 무작위 순서로 노출합니다.
# 구독해주셔서 감사합니다
# 이상규 기자의 기사는언론사별에서 볼 수 있습니다
# 이러니 BJ 하려고 난리지…‘별풍선’ 덕에 한달에만 34억 터졌다
# 구독해주셔서 감사합니다
# 이미나 기자의 기사는언론사별에서 볼 수 있습니다
# 관객 수 조작 영화 '비상선언'·'뜨거운피', 국비 지원금 받았다
# 구독해주셔서 감사합니다
# 권남영 기자의 기사는언론사별에서 볼 수 있습니다
# 與 ‘임명직’ 지도부 일괄사퇴…‘선출직’ 김기현 등 제외
# 구독해주셔서 감사합니다
# 김유민 기자의 기사는언론사별에서 볼 수 있습니다
# [속보] 軍 “북한, 하마스 식으로 기습공격 가능성”
# 구독해주셔서 감사합니다
# 김채현 기자의 기사는언론사별에서 볼 수 있습니다
# “나 취했어요”…고속도로서 ‘음주운전’ 생중계한 유튜버
# 구독해주셔서 감사합니다
# 이원율 기자의 기사는언론사별에서 볼 수 있습니다
# 유승민 “尹정부 ‘의대 정원확대’, 적극 지지…반드시 필요한 정책”
# 구독해주셔서 감사합니다
# 이지희 기자의 기사는언론사별에서 볼 수 있습니다
# "부모에 말하지마" 지적장애 女직원 수차례 성폭행한 50대 빵집사장
# 구독해주셔서 감사합니다
# 김명일 기자의 기사는언론사별에서 볼 수 있습니다
# ‘재판 노쇼’ 권경애 측 “나도 정신적 충격, 유족 손해배상 기각돼야”
# 구독해주셔서 감사합니다
# 권준영 기자의 기사는언론사별에서 볼 수 있습니다
# ‘말기암 투병’ 전여옥, 안타까운 근황 “오늘부터 물 먹을 수 있어서…”
# 구독해주셔서 감사합니다
# 김은빈 기자의 기사는언론사별에서 볼 수 있습니다
# 식당만 살리나유? 의식 잃은 직원 살린 '장교 출신' 백종원
# 구독해주셔서 감사합니다
# 하수영 기자의 기사는언론사별에서 볼 수 있습니다
# 유승민 "12월쯤 당 떠날지 말지 선택…신당은 최후 수단"
# 구독해주셔서 감사합니다
# 김현주 기자의 기사는언론사별에서 볼 수 있습니다
# 성관계 중 부상…치료비 뜯어낸 30대 공무원 항소심도 ‘실형’
# 구독해주셔서 감사합니다
# 김수영 기자의 기사는언론사별에서 볼 수 있습니다
# '드림아카데미' 18인, K-스타일로 찍은 생애 첫 화보
# 구독해주셔서 감사합니다
# 박지혜 기자의 기사는언론사별에서 볼 수 있습니다
# "중학생이라 소리쳤지만 수갑 채워" 흉기난동 오인 경찰, 그 이후
# 구독해주셔서 감사합니다
# 이가영 기자의 기사는언론사별에서 볼 수 있습니다
# 3년 전 의대 증원 반대했던 100만 의사 유튜버, 이번엔 “분위기 다르다”
# 구독해주셔서 감사합니다
# 이상규 기자의 기사는언론사별에서 볼 수 있습니다
# 이러니 BJ 하려고 난리지…‘별풍선’ 덕에 한달에만 34억 터졌다
# 구독해주셔서 감사합니다
# 이미나 기자의 기사는언론사별에서 볼 수 있습니다
# 관객 수 조작 영화 '비상선언'·'뜨거운피', 국비 지원금 받았다
# 구독해주셔서 감사합니다
# 남형도 기자의 기사는언론사별에서 볼 수 있습니다
# '깨갱' 강아지 때려죽인 영상에…보던 경찰도 고개 떨궜다
# 구독해주셔서 감사합니다
# 연승 기자의 기사는언론사별에서 볼 수 있습니다
# "현실 도피"…페미니즘 영화 보러 中 20대女 수억명 극장 몰려갔더니 벌어진 일
# 구독해주셔서 감사합니다
# 권남영 기자의 기사는언론사별에서 볼 수 있습니다
# 與 ‘임명직’ 지도부 일괄사퇴…‘선출직’ 김기현 등 제외
# 구독해주셔서 감사합니다
# 황재하 기자의 기사는언론사별에서 볼 수 있습니다
# [방송소식] 대학생들의 두뇌 서바이벌…쿠팡플레이 '대학전쟁'
# 구독해주셔서 감사합니다
# 노정동 기자의 기사는언론사별에서 볼 수 있습니다
# 혼다 11세대 '올 뉴 어코드' 출시…4390만원부터
# 구독해주셔서 감사합니다
# 김명일 기자의 기사는언론사별에서 볼 수 있습니다
# ‘재판 노쇼’ 권경애 측 “나도 정신적 충격, 유족 손해배상 기각돼야”
# 구독해주셔서 감사합니다
# 김현주 기자의 기사는언론사별에서 볼 수 있습니다
# 중앙지검장 “이재명 혐의, 하나 하나 중대사안이고 구속사안”
# 구독해주셔서 감사합니다
# 정윤주 기자의 기사는언론사별에서 볼 수 있습니다
# 사기 규모 얼마나 크길래...미얀마서 中 온라인 사기단 수천 명 송환
# 구독해주셔서 감사합니다
# 문영진 기자의 기사는언론사별에서 볼 수 있습니다
# '환자' 대신 돈받고 '아이돌' 태운 구급차…가수 김태우도 약식기소
# 구독해주셔서 감사합니다
# 김유진 기자의 기사는언론사별에서 볼 수 있습니다
# [영상] “120kg 스모 선수들 단체 탑승”…깜짝 놀란 日항공사 대처 봤더니
# 구독해주셔서 감사합니다
# 성수영 기자의 기사는언론사별에서 볼 수 있습니다
# 장욱진, 韓 경매시장 침체 방어카드로 등판
# 구독해주셔서 감사합니다
# 권윤희 기자의 기사는언론사별에서 볼 수 있습니다
# 간호법 이어 의대 증원도 안된다는 의협…‘강력투쟁’ 경고, 이유는?
# 구독해주셔서 감사합니다
# 백수전 기자의 기사는언론사별에서 볼 수 있습니다
# 하마스 총알 100발 맞고도 탈출…"테슬라 덕분에 살았다" [테슬람 X랩]
# 이 기사를 본 이용자들이 함께 많이 본 기사, 해당 기사와 유사한 기사, 관심 기사 등을 자동 추천합니다
# 본문 듣기를 종료하였습니다.
#
# 로그인
# 전체서비스
#
#
#
# 서비스안내
# 뉴스도움말
# 오류신고
#
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며, 이를 무단이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.
# ⓒ NAVER Corp.
# ⓒ SBS

# %%
# 바로 위의 코드 짤려서 안보여서 다시 씀
# Extracting all paragraphs from the page
# p로 태그된 것(<p로 시작하는 부분)을 전부 찾음

# paragraphs = soup.find_all('p')
# for p in paragraphs:
#     print(p.text) # .text로 글씨만

print('abc')
# Out:
# abc

# %%
# 바로 위의 paragraphs를 10줄만 출력하는 코드
paragraphs = soup.find_all('p')
for i, p in enumerate(paragraphs):
    if i < 10:
        print(p.text)
    else:
        break
# Out:
# 언론사를 구독하면 메인에서 바로 볼 수 있어요!
#
#
# SBS 언론사 구독 해지되었습니다.
#
#
# 언론사가 심층기획 기사로선정한 기사입니다.
# 언론사별 바로가기
# 닫기
#
# 이동 통신망을 이용하여 음성을 재생하면 별도의 데이터 통화료가 부과될 수 있습니다.
#
# 박찬범 기자 cbcb@sbs.co.kr
#
# ‘하나라도 더 알려주고 싶은 기자'
# Copyright ⓒ SBS. All rights reserved. 무단 전재, 재배포 및 AI학습 이용 금지
# 기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. 언론사는 개별 기사를 2개 이상 섹션으로 중복 분류할 수 있습니다.
# 구독
# 메인에서 바로 보는 언론사 편집 뉴스 지금 바로 구독해보세요!

# %% [markdown]
# **Extracting Links**

# %%
# Extracting all links from the page
links = soup.find_all('a')
for link in links:
    # print(link)
    print(link.get('href'))

# 결과에서 #으로 출력된 것은 실패한 쓰레기다.
# Out:
# #ct
# #
# https://www.naver.com
# https://news.naver.com
# https://media.naver.com/press/055
# #
# https://media.naver.com/press/055
# https://media.naver.com/press/055/premium
# https://media.naver.com/press/055/shortform
# https://media.naver.com/press/055?sid=100#lnb
# https://media.naver.com/press/055?sid=101#lnb
# https://media.naver.com/press/055?sid=102#lnb
# https://media.naver.com/press/055?sid=103#lnb
# https://media.naver.com/press/055?sid=104#lnb
# https://media.naver.com/tv/055
# https://media.naver.com/press/055/live
# https://media.naver.com/press/055/ranking
# http://news.sbs.co.kr/
# #
# https://news.sbs.co.kr/news/endPage.do?news_id=N1007384412&plink=ORI&cooper=NAVER
# https://media.naver.com/journalist/055/72366
# https://media.naver.com/journalist/055/72366
# None
# #
# #
# #
# #
# #
# /article/comment/055/0001097646
# javascript:;
# https://help.naver.com/alias/news/news_022.naver
# javascript:;
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# https://media.naver.com/journalist/055/72366
# https://media.naver.com/journalist/055/72366
# #
# #
# /article/055/0001096509?type=journalists
# /article/055/0001096780?type=journalists
# #
# #
# #
# #
# https://media.naver.com/channel/promotion?oid=055
# https://news.sbs.co.kr/news/inform.do?plink=FOOT&amp;cooper=NAVER
# /article/055/0000870156
# /article/055/0000892381
# /article/055/0001094340
# /article/055/0000882669
# /article/055/0000854933
# /article/055/0000835698
# /article/055/0000870157
# /article/055/0000892651
# /article/055/0000882913
# /article/055/0000841340
# http://news.sbs.co.kr/
# https://news.sbs.co.kr/news/endPage.do?news_id=N1007384141&oaid=N1007384412&plink=REL1&cooper=NAVER
# https://news.sbs.co.kr/news/endPage.do?news_id=N1007383663&oaid=N1007384412&plink=REL2&cooper=NAVER
# https://news.sbs.co.kr/news/endPage.do?news_id=N1007383655&oaid=N1007384412&plink=REL3&cooper=NAVER
# https://news.sbs.co.kr/news/endPage.do?news_id=N1007383659&oaid=N1007384412&plink=REL4&cooper=NAVER
# https://news.sbs.co.kr/news/endPage.do?news_id=N1007384127&oaid=N1007384412&plink=REL5&cooper=NAVER
# #
# #
# #
# #
# #
# #
# #
# #
# #
# https://media.naver.com/channel/seriesSetting
# #
# https://news.naver.com/hotissue/main?sid1=110&cid=1082871
# https://n.news.naver.com/mnews/hotissue/article/055/0001097647?type=series&cid=1082871
# https://n.news.naver.com/mnews/hotissue/article/055/0001097646?type=series&cid=1082871
# https://n.news.naver.com/mnews/hotissue/article/055/0001097575?type=series&cid=1082871
# https://media.naver.com/press/055
# https://media.naver.com/press/055
# /article/055/0001098127
# /article/055/0001098130
# /article/055/0001098138
# /article/055/0001098139
# /article/055/0001098135
# /article/055/0001098136
# /article/comment/055/0001097646
# https://mnews.sbs.co.kr/news/endPage.do?newsId=N1007384412&plink=ORI&cooper=NAVER
# https://media.naver.com/press/055
# /article/055/0001098127
# /article/055/0001098130
# /article/055/0001098138
# /article/055/0001098139
# /article/055/0001098135
# /article/055/0001098136
# https://media.naver.com/algorithm
# https://media.naver.com/press/055/ranking
# https://media.naver.com/press/055/ranking?type=comment
# #
# #
# /article/055/0001098139?ntype=RANKING
# /article/055/0001098138?ntype=RANKING
# /article/055/0001098062?ntype=RANKING
# /article/055/0001098135?ntype=RANKING
# /article/055/0001098120?ntype=RANKING
# /article/055/0001098081?ntype=RANKING
# /article/055/0001098130?ntype=RANKING
# /article/055/0001098138?ntype=RANKING
# /article/055/0001098128?ntype=RANKING
# /article/055/0001098111?ntype=RANKING
# #
# #
# https://media.naver.com/journalist/009/21611
# https://media.naver.com/journalist/009/21611
# #
# #
# https://media.naver.com/press/009
# https://media.naver.com/journalist/009/21611
# https://media.naver.com/journalist/015/25221
# https://media.naver.com/journalist/015/25221
# #
# #
# https://media.naver.com/press/015
# https://media.naver.com/journalist/015/25221
# https://media.naver.com/journalist/005/36786
# https://media.naver.com/journalist/005/36786
# #
# #
# https://media.naver.com/press/005
# https://media.naver.com/journalist/005/36786
# https://media.naver.com/journalist/081/30503
# https://media.naver.com/journalist/081/30503
# #
# #
# https://media.naver.com/press/081
# https://media.naver.com/journalist/081/30503
# https://media.naver.com/journalist/081/54357
# https://media.naver.com/journalist/081/54357
# #
# #
# https://media.naver.com/press/081
# https://media.naver.com/journalist/081/54357
# https://media.naver.com/journalist/016/34583
# https://media.naver.com/journalist/016/34583
# #
# #
# https://media.naver.com/press/016
# https://media.naver.com/journalist/016/34583
# https://media.naver.com/journalist/119/74986
# https://media.naver.com/journalist/119/74986
# #
# #
# https://media.naver.com/press/119
# https://media.naver.com/journalist/119/74986
# https://media.naver.com/journalist/023/76074
# https://media.naver.com/journalist/023/76074
# #
# #
# https://media.naver.com/press/023
# https://media.naver.com/journalist/023/76074
# https://media.naver.com/journalist/029/75751
# https://media.naver.com/journalist/029/75751
# #
# #
# https://media.naver.com/press/029
# https://media.naver.com/journalist/029/75751
# https://media.naver.com/journalist/025/38119
# https://media.naver.com/journalist/025/38119
# #
# #
# https://media.naver.com/press/025
# https://media.naver.com/journalist/025/38119
# https://media.naver.com/journalist/025/76378
# https://media.naver.com/journalist/025/76378
# #
# #
# https://media.naver.com/press/025
# https://media.naver.com/journalist/025/76378
# https://media.naver.com/journalist/022/59968
# https://media.naver.com/journalist/022/59968
# #
# #
# https://media.naver.com/press/022
# https://media.naver.com/journalist/022/59968
# https://media.naver.com/journalist/015/72236
# https://media.naver.com/journalist/015/72236
# #
# #
# https://media.naver.com/press/015
# https://media.naver.com/journalist/015/72236
# https://media.naver.com/journalist/018/31705
# https://media.naver.com/journalist/018/31705
# #
# #
# https://media.naver.com/press/018
# https://media.naver.com/journalist/018/31705
# https://media.naver.com/journalist/023/76070
# https://media.naver.com/journalist/023/76070
# #
# #
# https://media.naver.com/press/023
# https://media.naver.com/journalist/023/76070
# https://media.naver.com/journalist/009/21611
# https://media.naver.com/journalist/009/21611
# #
# #
# https://media.naver.com/press/009
# https://media.naver.com/journalist/009/21611
# https://media.naver.com/journalist/015/25221
# https://media.naver.com/journalist/015/25221
# #
# #
# https://media.naver.com/press/015
# https://media.naver.com/journalist/015/25221
# https://media.naver.com/journalist/008/31440
# https://media.naver.com/journalist/008/31440
# #
# #
# https://media.naver.com/press/008
# https://media.naver.com/journalist/008/31440
# https://media.naver.com/journalist/011/35977
# https://media.naver.com/journalist/011/35977
# #
# #
# https://media.naver.com/press/011
# https://media.naver.com/journalist/011/35977
# https://media.naver.com/journalist/005/36786
# https://media.naver.com/journalist/005/36786
# #
# #
# https://media.naver.com/press/005
# https://media.naver.com/journalist/005/36786
# https://media.naver.com/journalist/001/79876
# https://media.naver.com/journalist/001/79876
# #
# #
# https://media.naver.com/press/001
# https://media.naver.com/journalist/001/79876
# https://media.naver.com/journalist/015/25205
# https://media.naver.com/journalist/015/25205
# #
# #
# https://media.naver.com/press/015
# https://media.naver.com/journalist/015/25205
# https://media.naver.com/journalist/023/76074
# https://media.naver.com/journalist/023/76074
# #
# #
# https://media.naver.com/press/023
# https://media.naver.com/journalist/023/76074
# https://media.naver.com/journalist/022/59968
# https://media.naver.com/journalist/022/59968
# #
# #
# https://media.naver.com/press/022
# https://media.naver.com/journalist/022/59968
# https://media.naver.com/journalist/052/33574
# https://media.naver.com/journalist/052/33574
# #
# #
# https://media.naver.com/press/052
# https://media.naver.com/journalist/052/33574
# https://media.naver.com/journalist/014/78069
# https://media.naver.com/journalist/014/78069
# #
# #
# https://media.naver.com/press/014
# https://media.naver.com/journalist/014/78069
# https://media.naver.com/journalist/016/47388
# https://media.naver.com/journalist/016/47388
# #
# #
# https://media.naver.com/press/016
# https://media.naver.com/journalist/016/47388
# https://media.naver.com/journalist/015/38178
# https://media.naver.com/journalist/015/38178
# #
# #
# https://media.naver.com/press/015
# https://media.naver.com/journalist/015/38178
# https://media.naver.com/journalist/081/72143
# https://media.naver.com/journalist/081/72143
# #
# #
# https://media.naver.com/press/081
# https://media.naver.com/journalist/081/72143
# https://media.naver.com/journalist/015/30468
# https://media.naver.com/journalist/015/30468
# #
# #
# https://media.naver.com/press/015
# https://media.naver.com/journalist/015/30468
# /article/055/0001097932
# /article/023/0003793791
# /article/052/0001948023
# /article/005/0001644865
# /article/296/0000070499
# /article/055/0001097973
# /article/001/0014268542
# /article/016/0002210902
# /article/029/0002830771
# /article/018/0005597663
# /article/001/0014269369
# /article/003/0012150290
# /article/009/0005200720
# /article/022/0003865360
# /article/214/0001305621
# /article/003/0012151291
# /article/047/0002409718
# /article/421/0007114559
# /article/277/0005327377
# /article/057/0001774639
# /article/656/0000066232
# /article/015/0004903091
# /article/437/0000363555
# /article/008/0004950023
# /article/052/0001948130
# /article/015/0004903325
# /article/437/0000363554
# /article/032/0003255248
# /article/009/0005200725
# /article/025/0003314803
# #
# https://nid.naver.com/nidlogin.login?svctype=262144
# https://m.naver.com/services.html?f=svc.news
# https://m.news.naver.com/ombudsman/index
# https://help.naver.com/alias/news/news_007.naver
# https://help.naver.com/alias/news/news_001.naver
# https://www.navercorp.com
# None
# #
# #

# %% [markdown]
# **Extracting with Class and ID**

# %%
# Extracting elements with a specific class
specific_class_elements = soup.find_all(class_='specific-class') # '' 안에 있는 부분을 단축키f 처럼 찾는 기능
print(specific_class_elements)

# Extracting elements with a specific ID
specific_id_elements = soup.find_all(id='_CHANNEL_MAIN_PROMOTION') # '' 안에 있는 부분을 단축키f 처럼 찾는 기능
print(specific_id_elements)
# Out:
# []
# [<p class="ofhd_float_subscribe_tooltip" id="_CHANNEL_MAIN_PROMOTION" style="display:none;">
# <span class="ofhd_float_subscribe_tooltip_text"><strong>언론사를 구독하면 메인</strong>에서 바로 볼 수 있어요!</span>
# </p>]

# %% [markdown]
# **Navigating the Tree Structure**

# %%
# Accessing the first child of an element
first_child = soup.p.contents[0]
print(first_child)

print('\n')

# Accessing the parent of an element
parent_element = soup.p.parent # 그 부분을 감싸고 있는 엄마를 뽑음
print(parent_element)

print('\n')

# 동일 구조는 sister(?)
sister_element = soup.p.sister
print(sister_element)
# Out:
# <div class="ofhd_float_subscribe _CHANNEL_BUTTON_WRAP" style="display:none;">
# <button class="_channel_add ofhd_float_subscribe_btn _CHANNEL_BUTTON _CHANNEL_ADD" data-clk-add="chmain055" data-clk-remove="chdelete055" data-delay="1000" data-notification="true" data-notification-clk="notru" data-text="구독" type="button">구독</button>
# <p class="ofhd_float_subscribe_tooltip" id="_CHANNEL_MAIN_PROMOTION" style="display:none;">
# <span class="ofhd_float_subscribe_tooltip_text"><strong>언론사를 구독하면 메인</strong>에서 바로 볼 수 있어요!</span>
# </p>
# <a class="ofhd_float_subscribe_layer _add _LINK" data-url-type="NAVERAPP_NEWS_CHANNEL" href="#" id="_CHANNEL_LAYER_055_0001097646" style="display: none;">
# <span class="ofhd_float_subscribe_layer_text">메인 뉴스판에서 SBS 주요뉴스를 <br/> 볼 수 있습니다.</span>
# <span class="ofhd_float_subscribe_layer_link">보러가기</span>
# </a>
# <p class="ofhd_float_subscribe_layer _remove" id="_CHANNEL_REMOVE_LAYER_055_0001097646" style="display: none;">
# <span class="ofhd_float_subscribe_layer_text"><strong>SBS</strong> 언론사 구독 해지되었습니다.</span>
# </p>
# </div>
#
#
# None
